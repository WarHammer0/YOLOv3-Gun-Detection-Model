# %% [markdown]
# # Mounting Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # NVIDIA GPGPU and CUDA version Check

# %%
# !nvcc --version
# !nvidia-smi
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2019 NVIDIA Corporation
# Built on Sun_Jul_28_19:07:16_PDT_2019
# Cuda compilation tools, release 10.1, V10.1.243
# Mon May  4 00:09:56 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.64.00    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# # Unzipping Folder Content

# %%
# !unzip "/content/drive/My Drive/Group7YOLOv3COLAB.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: Group7YOLOv3COLAB/data/images/armas (2037).jpg
#   inflating: Group7YOLOv3COLAB/data/images/armas (2038).jpg
#   inflating: Group7YOLOv3COLAB/data/images/armas (2039).jpg
#   inflating: Group7YOLOv3COLAB/data/images/armas (204).jpg
#   inflating: Group7YOLOv3COLAB/data/images/armas (2040).jpg
#   inflating: Group7YOLOv3COLAB/data/images/armas (2041).jpg
#   inflating: Group7YOLOv3COLAB/data/images/armas (2042).jpg
#   inflating: Group7YOLOv3COLAB/data/images/armas (2043).jpg
#   inflating: Group7YOLOv3COLAB/data/images/armas (2044).jpg
#   inflating: Group7YOLOv3COLAB/data/images/armas (2045).jpg
#   inflating: Group7YOLOv3COLAB/data/images/armas (2046).jpg
#   inflating: Group7YOLOv3COLAB/data/images/armas (2047).jpg
#  extracting: Group7YOLOv3COLAB/data/images/armas (2048).jpg
#   inflating: Group7YOLOv3COLAB/data/images/armas (2049).jpg
#   inflating: Group7YOLOv3COLAB/data/images/armas (205).jpg
# ...

# %% [markdown]
# # Building Darknet Executable

# %%
# %cd /content/Group7YOLOv3COLAB 
# !make
# !chmod +x ./darknet
# Out:
# /content/Group7YOLOv3COLAB
# make: Nothing to be done for 'all'.

# %% [markdown]
# # Creating Symbolic Link for Backup Folder

# %%
# !rm /content/Group7YOLOv3COLAB/backup -r
# !ln -s /content/drive/'My Drive'/backup /content/Group7YOLOv3COLAB

# %% [markdown]
# # Installing DOS to UNIX Converter

# %%
# !sudo apt install dos2unix
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# dos2unix is already the newest version (7.3.4-3).
# 0 upgraded, 0 newly installed, 0 to remove and 25 not upgraded.

# %%
# !dos2unix ./data/train.txt
# !dos2unix ./data/val.txt
# !dos2unix ./data/yolo.data
# !dos2unix ./data/yolo.names
# !dos2unix ./cfg/yolov3_custom_train.cfg
# Out:
# dos2unix: converting file ./data/train.txt to Unix format...
# dos2unix: converting file ./data/val.txt to Unix format...
# dos2unix: converting file ./data/yolo.data to Unix format...
# dos2unix: converting file ./data/yolo.names to Unix format...
# dos2unix: converting file ./cfg/yolov3_custom_train.cfg to Unix format...

# %% [markdown]
# # Training the Model with new Dataset and Pretrained Darknet Model as Baseline

# %%
# %cd /content/Group7YOLOv3COLAB
# !./darknet detector train data/yolo.data cfg/yolov3_custom_train.cfg model/PreTrained/darknet53.conv.74
# Out:
# Streaming output truncated to the last 5000 lines.
# Region 82 Avg IOU: 0.889249, Class: 0.999648, Obj: 0.981645, No Obj: 0.002032, .5R: 1.000000, .75R: 1.000000,  count: 4
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000000, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000000, .5R: -nan, .75R: -nan,  count: 0
# Region 82 Avg IOU: 0.881833, Class: 0.998874, Obj: 0.908754, No Obj: 0.004513, .5R: 1.000000, .75R: 1.000000,  count: 11
# Region 94 Avg IOU: 0.874954, Class: 0.999701, Obj: 0.650615, No Obj: 0.000242, .5R: 1.000000, .75R: 1.000000,  count: 2
# Region 106 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000000, .5R: -nan, .75R: -nan,  count: 0
# Region 82 Avg IOU: 0.841989, Class: 0.999817, Obj: 0.980509, No Obj: 0.002000, .5R: 1.000000, .75R: 0.750000,  count: 4
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000000, .5R: -nan, .75R: -nan,  count: 0
# ...
